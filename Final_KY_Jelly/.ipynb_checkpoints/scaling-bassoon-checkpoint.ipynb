# %%
import cobra
import matplotlib.pyplot as plt
import multiprocessing as mp
import numpy as np
import pandas as pd
import scipy.stats

from time import time
from operator import itemgetter

# %%
Recon3D = cobra.io.load_matlab_model('Recon3D.mat')

# %%
# Read in scRNAseq data set
data = pd.read_csv('GSE115469_Data.csv', index_col=0)

# %%
# modifiable variables: cell # (max 8444), gene # (max 1800), threshold is % unique cells
cells = 8444
genes = 1800
threshold = .875
threads = mp.cpu_count() - 1
plot = False

# Set objective values for alcohol
Recon3D.reactions.get_by_id("ETOHt").lower_bound = 1000
Recon3D.reactions.get_by_id("ETOHt").upper_bound = 1000
Recon3D.objective = "ALCD2x"

# Gene names should be the 0th column, which is the index column
genes_in_sc = data.index

# Read in the map from gene name -> model name
with open("map.txt", "r") as f:
    list_dict = f.readline().split(";")
    
gene_info = {}

for i in list_dict:
    if i == '':
        continue
    tempkey = i.split(',')[0]
    tempval = i.split(',')[1]
    gene_info[tempkey] = tempval
    
# find all genes that exist in the scRNAseq set and in the model
gene_matches = [genes_in_sc[i] for i in range(len(genes_in_sc)) if genes_in_sc[i] in gene_info.keys()]

# %%
def optimize_for_gene(num, i, name, expression):
    # return flux balance analysis result for a particular gene and cell #
    print("Gene #: %d Cell #: %d, Model Start" % (num, i), end = "\r", flush = True)
    global Recon3D
    with Recon3D as model:
        # get expression data from the scRNAseq data set
        # expression = data.loc[name][cell_num]
        # retrieve the reaction for the gene
        reactions = model.genes.get_by_id(gene_info[name]).reactions
        
        # change bounds for all reactions associated with the gene
        for j in reactions:
            j.lower_bound = 2 ** expression * 100
            j.upper_bound = 2 ** expression * 100
        fbas = model.optimize('maximize')
        
        # return gene name, cell #, and objective value so that we can recover
        # results from multiprocessing
        return [name, fbas.objective_value]

# %%
from test import optimize_for_each_gene

# prepare a list to receive the ApplyResult objects from multiprocessing
results = []

# prepare a list to make plotting axes easier
dimnames = []

# do FBA on the first 10 genes to make it faster for now
if __name__ == "__main__":
    p = mp.Pool(processes = threads)
    
    for num in range(len(gene_matches)):
        # find unique expression levels
        unique_expression_levels, ucind = np.unique(data.loc[gene_matches[num]][:cells], return_inverse = True)

        if len(unique_expression_levels) < threshold * cells:
            print('Skipping Gene %i' % (num))
            continue

        for i in range(len(unique_expression_levels)):
            # find the place where the unique expression levels are 
            cell_locs = np.where(ucind == i)

            # put the ApplyResult object in a list
            async_result = p.apply_async(optimize_for_each_gene, args = (Recon3D, gene_info, num, i, gene_matches[num], unique_expression_levels[i]))
            result = async_result.get() 
            #result = optimize_for_gene(num, i, gene_matches[num], unique_expression_levels[i])

            # record instances of unique expression level results
            for ind in cell_locs:
                results.append([result, num, ind])
# Out:
# Skipping Gene 0
# Skipping Gene 1
# Skipping Gene 2
# Skipping Gene 3
# Skipping Gene 4
# Skipping Gene 5
# Skipping Gene 6
# Skipping Gene 7
# Skipping Gene 8
# Skipping Gene 9
# Skipping Gene 10
# Skipping Gene 11
# Skipping Gene 12
# Skipping Gene 13
# Skipping Gene 14
# Skipping Gene 15
# Skipping Gene 16
# Skipping Gene 17
# Skipping Gene 18
# Skipping Gene 19
# Skipping Gene 20
# Skipping Gene 21
# Skipping Gene 22
# Skipping Gene 23
# Skipping Gene 24
# Skipping Gene 25
# Skipping Gene 26
# Skipping Gene 27
# Skipping Gene 28
# Skipping Gene 29
# Skipping Gene 30
# Skipping Gene 31
# Skipping Gene 32
# Skipping Gene 33
# Skipping Gene 34
# Skipping Gene 35
# Skipping Gene 36
# Skipping Gene 37
# Skipping Gene 38
# Skipping Gene 39
# Skipping Gene 40
# Skipping Gene 41
# Skipping Gene 42
# Skipping Gene 43
# Skipping Gene 44
# Skipping Gene 45
# Skipping Gene 46
# Skipping Gene 47
# Skipping Gene 48
# Skipping Gene 49
# Skipping Gene 50
# Skipping Gene 51
# Skipping Gene 52
# Skipping Gene 53
# Skipping Gene 54
# Skipping Gene 55
# Skipping Gene 56
# Skipping Gene 57
# Skipping Gene 58
# Skipping Gene 59
# Skipping Gene 60
# Skipping Gene 61
# Skipping Gene 62
# Skipping Gene 63
# Skipping Gene 64
# Skipping Gene 65
# Skipping Gene 66
# Skipping Gene 67
# Skipping Gene 68
# Skipping Gene 69
# Skipping Gene 70
# Skipping Gene 71
# Skipping Gene 72
# Skipping Gene 73
# Skipping Gene 74
# Skipping Gene 75
# Skipping Gene 76
# Skipping Gene 77
# Skipping Gene 78
# Skipping Gene 79
# Skipping Gene 80
# Skipping Gene 81
# Skipping Gene 82
# Skipping Gene 83
# Skipping Gene 84
# Skipping Gene 85
# Skipping Gene 86
# Skipping Gene 87
# Skipping Gene 88
# Skipping Gene 89
# Skipping Gene 90
# Skipping Gene 91
# Skipping Gene 92
# Skipping Gene 93
# Skipping Gene 94
# Skipping Gene 95
# Skipping Gene 96
# Skipping Gene 97
# Skipping Gene 98
# Skipping Gene 99
# Skipping Gene 100
# Skipping Gene 101
# Skipping Gene 102
# Skipping Gene 103
# Skipping Gene 104
# Skipping Gene 105
# Skipping Gene 106
# Skipping Gene 107
# Skipping Gene 108
# Skipping Gene 109
# Skipping Gene 110
# Skipping Gene 111
# Skipping Gene 112
# Skipping Gene 113
# Skipping Gene 114
# Skipping Gene 115
# Skipping Gene 116
# Skipping Gene 117
# Skipping Gene 118
# Skipping Gene 119
# Skipping Gene 120
# Skipping Gene 121
# Skipping Gene 122
# Skipping Gene 123
# Skipping Gene 124
# Skipping Gene 125
# Skipping Gene 126
# Skipping Gene 127
# Skipping Gene 128
# Skipping Gene 129
# Skipping Gene 130
# Skipping Gene 131
# Skipping Gene 132
# Skipping Gene 133
# Skipping Gene 134
# Skipping Gene 135
# Skipping Gene 136
# Skipping Gene 137
# Skipping Gene 138
# Skipping Gene 139
# Skipping Gene 140
# Skipping Gene 141
# Skipping Gene 142
# Skipping Gene 143
# Skipping Gene 144
# Skipping Gene 145
# Skipping Gene 146
# Skipping Gene 147
# Skipping Gene 148
# Skipping Gene 149
# Skipping Gene 150
# Skipping Gene 151
# Skipping Gene 152
# Skipping Gene 153
# Skipping Gene 154
# Skipping Gene 155
# Skipping Gene 156
# Skipping Gene 157
# Skipping Gene 158
# Skipping Gene 159
# Skipping Gene 160
# Skipping Gene 161
# Skipping Gene 162
# Skipping Gene 163
# Skipping Gene 164
# Skipping Gene 165
# Skipping Gene 166
# Skipping Gene 167
# Skipping Gene 168
# Skipping Gene 169
# Skipping Gene 170
# Skipping Gene 171
# Skipping Gene 172
# Skipping Gene 173
# Skipping Gene 174
# Skipping Gene 175
# Skipping Gene 176
# Skipping Gene 177
# Skipping Gene 178
# Skipping Gene 179
# Skipping Gene 180
# Skipping Gene 181
# Skipping Gene 182
# Skipping Gene 183
# Skipping Gene 184
# Skipping Gene 185
# Skipping Gene 186
# Skipping Gene 187
# Skipping Gene 188
# Skipping Gene 189
# Skipping Gene 190
# Skipping Gene 191
# Skipping Gene 192
# Skipping Gene 193
# Skipping Gene 194
# Skipping Gene 195
# Skipping Gene 196
# Skipping Gene 197
# Skipping Gene 198
# Skipping Gene 199
# Skipping Gene 200
# Skipping Gene 201
# Skipping Gene 202
# Skipping Gene 203
# Skipping Gene 204
# Skipping Gene 205
# Skipping Gene 206
# Skipping Gene 207
# Skipping Gene 208
# Skipping Gene 209
# Skipping Gene 210
# Skipping Gene 211
# Skipping Gene 212
# Skipping Gene 213
# Skipping Gene 214
# Skipping Gene 215
# Skipping Gene 216
# Skipping Gene 217
# Skipping Gene 218
# Skipping Gene 219
# Skipping Gene 220
# Skipping Gene 221
# Skipping Gene 222
# Skipping Gene 223
# Skipping Gene 224
# Skipping Gene 225
# Skipping Gene 226
# Skipping Gene 227
# Skipping Gene 228
# Skipping Gene 229
# Skipping Gene 230
# Skipping Gene 231
# Skipping Gene 232
# Skipping Gene 233
# Skipping Gene 234
# Skipping Gene 235
# Skipping Gene 236
# Skipping Gene 237
# Skipping Gene 238
# Skipping Gene 239
# Skipping Gene 240
# Skipping Gene 241
# Skipping Gene 242
# Skipping Gene 243
# Skipping Gene 244
# Skipping Gene 245
# Skipping Gene 246
# Skipping Gene 247
# Skipping Gene 248
# Skipping Gene 249
# Skipping Gene 250
# Skipping Gene 251
# Skipping Gene 252
# Skipping Gene 253
# Skipping Gene 254
# Skipping Gene 255
# Skipping Gene 256
# Skipping Gene 257
# Skipping Gene 258
# Skipping Gene 259
# Skipping Gene 260
# Skipping Gene 261
# Skipping Gene 262
# Skipping Gene 263
# Skipping Gene 264
# Skipping Gene 265
# Skipping Gene 266
# Skipping Gene 267
# Skipping Gene 268
# Skipping Gene 269
# Skipping Gene 270
# Skipping Gene 271
# Skipping Gene 272
# Skipping Gene 273
# Skipping Gene 274
# Skipping Gene 275
# Skipping Gene 276
# Skipping Gene 277
# Skipping Gene 278
# Skipping Gene 279
# Skipping Gene 280
# Skipping Gene 281
# Skipping Gene 282
# Skipping Gene 283
# Skipping Gene 284
# Skipping Gene 285
# Skipping Gene 286
# Skipping Gene 287
# Skipping Gene 288
# Skipping Gene 289
# Skipping Gene 290
# Skipping Gene 291
# Skipping Gene 292
# Skipping Gene 293
# Skipping Gene 294
# Skipping Gene 295
# Skipping Gene 296
# Skipping Gene 297
# Skipping Gene 298
# Skipping Gene 299
# Skipping Gene 300
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\Brian\Anaconda3\lib\multiprocessing\pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\Users\Brian\OneDrive - Johns Hopkins University\[JHU] FA.19\AS.250.313\Final Project\scaling-bassoon\Final_KY_Jelly\test.py", line 5, in optimize_for_each_gene
#     with Recon3D as model:
# NameError: name 'Recon3D' is not defined
# """
#
# The above exception was the direct cause of the following exception:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-31dd2bc4ac76> in <module>
#      25             # put the ApplyResult object in a list
#      26             async_result = p.apply_async(optimize_for_each_gene, args = (num, i, gene_matches[num], unique_expression_levels[i]))
# ---> 27             result = async_result.get()
#      28             #result = optimize_for_gene(num, i, gene_matches[num], unique_expression_levels[i])
#      29
#
# ~\Anaconda3\lib\multiprocessing\pool.py in get(self, timeout)
#     655             return self._value
#     656         else:
# --> 657             raise self._value
#     658
#     659     def _set(self, i, obj):
#
# NameError: name 'Recon3D' is not defined

# %%
# fetch the results of the ApplyResult object for the entire list
# make the ApplyResults into aa pandas dataframe to make it easier to sort
results_pd = pd.DataFrame.from_records(results)

# sort by gene # and cell # within gene #
results_pd = results_pd.sort_values([1, 2])
results_pd = results_pd.reset_index()

# get the result
results_fetched = [[results_pd.loc[i][0].get(), results_pd.loc[i][1], results_pd.loc[i][2]]
                   for i in range(results_pd.shape[0])]

# make it a pandas data frame so its easier to transform
df = pd.DataFrame.from_records(results_fetched)

# sort by the gene name first, then by the cell number within the gene name
df.sort_values(by=[1, 2])

# pivot converts a 1x10,0000 list to a 10x1,000 array with rownames that match
# unique values of column 0, and column names that match unique values of column 1
# and values that match column 2
df = df.pivot(index=1, columns=2, values=0)

# the dimnames should match the unique values of column 0 (gene names)
for i in range(int(results_pd.shape[0]/cells)):
    dimnames.append(df.iloc[i][0][0])
    
# convert the results back into a numpy array so that plotting is easer.
results_T = np.array(df.applymap(lambda x: x[1]))
filename = met_name + 'results' + str(threshold) + 'threshold' + str(cells) + 'cells' + '.txt.gz'
dimfilename = met_name + 'dimensions_of_results' + str(threshold) + 'threshold' + str(cells) + 'cells' + '.txt'
np.savetxt(filename, results_T)
dimf = open(dimfilename, 'w')
for i in dimnames:
    dimf.write(i + ';')
dimf.close()
